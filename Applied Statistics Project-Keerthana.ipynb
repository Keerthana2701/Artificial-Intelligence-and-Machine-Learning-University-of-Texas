# %% [markdown]
# ## Applied Statistics Project -Keerthana

# %%
# 1.Import the necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 2.Read the data as a data frame 

data=pd.read_csv('insurance.csv')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Exploratory Data Analysis-EDA

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# 3a. Shape of the data 
data.shape
# Out:
# (1338, 7)

# %%
# 3b. Data type of each attribute
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
# 3c. Checking the presence of missing values
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
#  ### we see that there are no missing values in dataset

# %%
# 3d.  5 point summary of numerical attribute -min,q1,q2,q3,max

# %%
q1=data.quantile(q=0.25)
q1
# Out:
# age           27.00000
# bmi           26.29625
# children       0.00000
# charges     4740.28715
# Name: 0.25, dtype: float64

# %%
q2=data.quantile(q=0.50)
q2
# Out:
# age           39.000
# bmi           30.400
# children       1.000
# charges     9382.033
# Name: 0.5, dtype: float64

# %%
q3=data.quantile(q=0.75)
q3
# Out:
# age            51.000000
# bmi            34.693750
# children        2.000000
# charges     16639.912515
# Name: 0.75, dtype: float64

# %%
IQR=q3-q1
IQR
# Out:
# age            24.000000
# bmi             8.397500
# children        2.000000
# charges     11899.625365
# dtype: float64

# %%
data.boxplot()

# %%
data.boxplot(column='age',return_type='axes',figsize=(8,8))

# %%
data.boxplot(column='bmi',return_type='axes',figsize=(8,8))

# %%
data.boxplot(column='children',return_type='axes',figsize=(8,8))

# %%
data.boxplot(column='charges',return_type='axes',figsize=(8,8))

plt.text(x=0.74, y=16000.00, s="3rd Quartile")
plt.text(x=0.8, y=9800.00, s="Median")
plt.text(x=0.75, y=5000.00, s="1st Quartile")
plt.text(x=0.9, y=92.00, s="Min")
plt.text(x=0.9, y=36000.00, s="Max")
plt.text(x=0.7, y=9800.5, s="IQR", rotation=90, size=25)
# Out:
# Text(0.7, 9800.5, 'IQR')

# %%
# 3e.Distribution of ‘bmi’, ‘age’ and ‘charges’ columns

# %%
sns.countplot('sex',data=data)

# %%
sns.boxplot(x='sex', y='charges', data= data)

# %%
data['age'].value_counts()
# Out:
# 18    69
# 19    68
# 51    29
# 45    29
# 46    29
# 47    29
# 48    29
# 50    29
# 52    29
# 20    29
# 26    28
# 54    28
# 53    28
# 25    28
# 24    28
# 49    28
# 23    28
# 22    28
# 21    28
# 27    28
# 28    28
# 31    27
# 29    27
# 30    27
# 41    27
# 43    27
# 44    27
# 40    27
# 42    27
# 57    26
# 34    26
# 33    26
# 32    26
# 56    26
# 55    26
# 59    25
# 58    25
# 39    25
# 38    25
# 35    25
# 36    25
# 37    25
# 63    23
# 60    23
# 61    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
sns.distplot(data['age'])

# %%
data['age'].hist(bins=10,color='Green')

# %%
sns.distplot(data['bmi'])

# %%
sns.distplot(data['charges'])

# %%
(data['age']).corr(data['bmi'])
# Out:
# 0.10927188154853519

# %%
(data['age']).corr(data['charges'])
# Out:
# 0.29900819333064776

# %%
plt.scatter(data['age'], data['bmi'], alpha=0.5)

# %%
sns.jointplot(data['age'], data['bmi'],kind="reg")

# %%
sns.barplot(data['age'], data['bmi'],hue=data['sex'])

# %%
sns.pointplot(data['age'], data['bmi'])

# %% [markdown]
# ### we see that majority of people are aged between 18-19
# ### age and bmi are less correlated
# ### majority of charges is in range 1000-2000

# %%
# 3f. Measure of skewness of ‘bmi’, ‘age’ and ‘charges’ columns

# %% [markdown]
# If skewness is less than -1 or greater than 1, the distribution is highly skewed.
# If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed.
# If skewness is between -0.5 and 0.5, the distribution is approximately symmetric.

# %%
data.skew(axis=0,skipna=True)
# Out:
# age         0.055673
# bmi         0.284047
# children    0.938380
# charges     1.515880
# dtype: float64

# %%
from scipy.stats import skew 
skew(data['age'])
# Out:
# 0.055610083072599126

# %%
from scipy.stats import skew 
skew(data['bmi'])
# Out:
# 0.28372857291709386

# %% [markdown]
# ### we see that bmi, age  is approximately symetric
# ### charges is highly skewed

# %%
## 3g. Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges'

# %%
## Discover outliers with visualization tools

# %%
data.boxplot(column='charges',return_type='axes',figsize=(8,8))

# %%
data.boxplot(column='age',return_type='axes',figsize=(8,8))

# %%
data.boxplot(column='bmi',return_type='axes',figsize=(8,8))

# %%
data.boxplot(figsize=(30,10))

# %% [markdown]
# ### bmi and charges have outliers. charges have more outliers

# %%
# Value of Oultiers

# %%
q125thpercentile= np.percentile(data['charges'], 25)
q125thpercentile
# Out:
# 4740.28715

# %%
q375thpercentile=np.percentile(data['charges'], 75)
q375thpercentile
# Out:
# 16639.912515

# %%
iqr = q375thpercentile-q125thpercentile
iqr
# Out:
# 11899.625365

# %%
threshold= iqr * 1.5
threshold
# Out:
# 17849.4380475

# %%
lowerrange=q125thpercentile-threshold
upperrange =q375thpercentile+threshold
print(lowerrange)
print(upperrange)
# Out:
# -13109.1508975
# 34489.350562499996

# %%
# outliers for charges

outlier = [x for x in data['charges'] if x < lowerrange or x > upperrange]
print(' outliers for charges:',len(outlier))
# Out:
#  outliers for charges: 139

# %% [markdown]
# ### outliers for charges: 139

# %%
q125thpercentile= np.percentile(data['bmi'], 25)
print(q125thpercentile)
q375thpercentile=np.percentile(data['bmi'], 75)
print(q375thpercentile)
# Out:
# 26.29625
# 34.69375

# %%
iqr = q375thpercentile-q125thpercentile
threshold= iqr * 1.5
lowerrange=q125thpercentile-threshold
upperrange =q375thpercentile+threshold
print(lowerrange)
print(upperrange)
# Out:
# 13.7
# 47.290000000000006

# %%
# outliers for bmi

outlier = [x for x in data['charges'] if x < lowerrange or x > upperrange]
print(' outliers for bmi:',len(outlier))
# Out:
#  outliers for bmi: 1338

# %% [markdown]
# ### outliers for bmi: 1338

# %%
# 3h. Distribution of categorical columns (include children)

# %%
sns.countplot('children',data=data)

# %%
sns.countplot(data['smoker'])

# %%
sns.boxplot(x='region', y='charges', data= data)

# %%
sns.countplot(data['smoker'],hue=data['sex'])

# %%
data.groupby('smoker')['bmi'].mean().plot(kind='barh',color='red')

# %%
data.groupby('sex')['bmi'].mean().plot(kind='barh',color='Green')

# %%
sns.factorplot(x='smoker',col='sex',kind='count',data=data)
# Out:
# C:\Users\Vikee\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.pairplot(data[['age','sex','bmi']]);

# %%
# 3i.Pair plot that includes all the columns of the data frame

# %%
sns.pairplot(data)

# %%
## 4a) Do charges of people who smoke differ significantly from thepeople who don't?

# %%
data.groupby('smoker')['charges'].mean().plot(kind='barh',color='Green')

# %% [markdown]
# ### we see from the visualization that charges of people who smoke differ significantly from thepeople who don't

# %% [markdown]
# ### Hypothesis
# ### Ho = charges of smokers does not differ significantly from that of non-smokers i.e charges are same.
# ### Ha = charges of smokers differ significantly from that of non-smokers i.e charges are different

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
smoker=data[data['smoker'] == 'yes']
non_smoker=data[data['smoker'] == 'no']
print("smokers count",data.smoker.value_counts()[1])
print("non smokers count",data.smoker.value_counts()[0])
# Out:
# smokers count 274
# non smokers count 1064

# %%
smoker_charges=smoker.charges
smoker_charges
smoker_charges=np.array(smoker_charges)
smoker_charges
# Out:
# array([16884.924  , 27808.7251 , 39611.7577 , 36837.467  , 37701.8768 ,
#        38711.     , 35585.576  , 51194.55914, 39774.2763 , 48173.361  ,
#        38709.176  , 23568.272  , 37742.5757 , 47496.49445, 34303.1672 ,
#        23244.7902 , 14711.7438 , 17663.1442 , 16577.7795 , 37165.1638 ,
#        39836.519  , 21098.55405, 43578.9394 , 30184.9367 , 47291.055  ,
#        22412.6485 , 15820.699  , 30942.1918 , 17560.37975, 47055.5321 ,
#        19107.7796 , 39556.4945 , 17081.08   , 32734.1863 , 18972.495  ,
#        20745.9891 , 40720.55105, 19964.7463 , 21223.6758 , 15518.18025,
#        36950.2567 , 21348.706  , 36149.4835 , 48824.45   , 43753.33705,
#        37133.8982 , 20984.0936 , 34779.615  , 19515.5416 , 19444.2658 ,
#        17352.6803 , 38511.6283 , 29523.1656 , 12829.4551 , 47305.305  ,
#        44260.7499 , 41097.16175, 43921.1837 , 33750.2918 , 17085.2676 ,
#        24869.8368 , 36219.40545, 46151.1245 , 17179.522  , 42856.838  ,
# ...

# %%
nonsmoker_charges=non_smoker.charges
nonsmoker_charges=np.array(nonsmoker_charges)
nonsmoker_charges
# Out:
# array([ 1725.5523 ,  4449.462  , 21984.47061, ...,  2205.9808 ,
#         1629.8335 ,  2007.945  ])

# %%
t_statistic, p_value = ttest_ind(smoker_charges, nonsmoker_charges)
print(t_statistic, p_value)
# Out:
# 46.664921172723716 8.271435842177219e-283

# %% [markdown]
# ### p-value of 8.271e-283 < 0.05.
# so we reject null hypothesis. Thus, charges of smokers differ significantly from that of non-smokers
#
# Ho = charges of smokers does not differ significantly from that of non-smokers i.e charges are same.
# Ha = charges of smokers differ significantly from that of non-smokers i.e charges are different
#
#
#
# ## So, we conclude charges of smokers differ significantly from that of non-smokers

# %%
## 4b) Does bmi of males differ significantly from that of females

# %%
data.groupby('sex')['bmi'].sum().plot(kind='barh',color='Green')

# %% [markdown]
# ### we see from visualization that bmi of males does not differ significantly from that of females

# %% [markdown]
# ### hypothesis
# ### Ho = bmi of males does not differ significantly from that of females
# ### Ha = bmi of males differ significantly from that of females

# %%
female=data[data['sex'] == 'female']
male=data[data['sex'] == 'male']
total_count=data.sex.value_counts()
female_count=data.sex.value_counts()[1]
male_count=data.sex.value_counts()[0]
print(total_count)
print(male_count)
print(female_count)
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# 676
# 662

# %%
female_bmi=female.bmi
##female_bmi
female_bmi=np.array(female_bmi)
female_bmi
# Out:
# array([27.9  , 25.74 , 33.44 , 27.74 , 25.84 , 26.29 , 39.82 , 30.78 ,
#        36.005, 32.4  , 31.92 , 27.72 , 23.085, 32.775, 26.315, 28.6  ,
#        32.965, 26.6  , 36.63 , 30.8  , 38.665, 34.77 , 24.53 , 35.625,
#        33.63 , 28.69 , 31.825, 22.88 , 37.335, 25.935, 22.42 , 28.9  ,
#        39.1  , 36.19 , 24.75 , 28.1  , 29.59 , 39.805, 32.965, 38.285,
#        41.23 , 34.8  , 31.16 , 27.2  , 27.74 , 26.98 , 39.49 , 24.795,
#        31.3  , 37.62 , 30.8  , 31.6  , 30.115, 29.92 , 27.5  , 28.4  ,
#        29.7  , 35.72 , 27.94 , 27.17 , 23.37 , 28.975, 33.915, 28.785,
#        28.3  , 37.4  , 17.765, 26.505, 22.04 , 35.9  , 28.785, 28.05 ,
#        31.9  , 36.   , 38.83 , 37.73 , 37.43 , 37.145, 23.37 , 25.46 ,
#        27.83 , 26.6  , 36.85 , 29.8  , 37.   , 33.155, 31.825, 34.8  ,
#        33.345, 37.7  , 28.9  , 33.155, 38.28 , 26.41 , 29.92 , 30.9  ,
#        32.2  , 32.11 , 26.2  , 26.6  , 32.8  , 28.6  , 18.05 , 39.33 ,
# ...

# %%
male_bmi=male.bmi
male_bmi=np.array(male_bmi)
male_bmi
# Out:
# array([33.77 , 33.   , 22.705, 28.88 , 29.83 , 26.22 , 34.4  , 42.13 ,
#        24.6  , 23.845, 40.3  , 35.3  , 34.1  , 28.025, 17.385, 36.3  ,
#        35.6  , 28.31 , 36.4  , 20.425, 20.8  , 36.67 , 39.9  , 21.78 ,
#        37.05 , 37.3  , 35.2  , 28.   , 34.43 , 36.955, 31.68 , 27.36 ,
#        33.66 , 24.7  , 26.315, 23.98 , 28.5  , 32.01 , 27.4  , 34.01 ,
#        35.53 , 26.885, 37.62 , 22.895, 29.83 , 34.77 , 38.28 , 19.95 ,
#        19.3  , 25.46 , 28.025, 30.875, 27.94 , 35.09 , 33.63 , 30.8  ,
#        32.205, 28.595, 49.06 , 37.1  , 23.75 , 31.35 , 34.7  , 25.555,
#        34.1  , 25.175, 22.42 , 32.49 , 25.3  , 29.735, 28.69 , 30.495,
#        28.4  , 24.13 , 29.7  , 39.52 , 24.42 , 25.175, 35.53 , 39.6  ,
#        29.64 , 28.215, 18.905, 41.47 , 30.3  , 15.96 , 27.835, 29.2  ,
#        28.595, 19.95 , 30.69 , 41.895, 31.57 , 25.74 , 34.43 , 30.59 ,
#        22.3  , 26.4  , 27.74 , 41.23 , 33.   , 30.875, 28.5  , 23.1  ,
# ...

# %%
t_statistic, p_value = ttest_ind(male_bmi, female_bmi)
print(t_statistic, p_value)
# Out:
# 1.696752635752224 0.08997637178984932

# %% [markdown]
# #### p-value of 0.08997 > 0.05.
# accpet null hypothesis
#
# Ho = bmi of males does not differ significantly from that of females
# Ha = bmi of males differ significantly from that of females
#
# p < alpha, reject null hypo --- the result is statistically significant
# p > alpha, fail to reject null hypo -----the result is not statistically significant
#
# ## So, we conclude bmi of males does not differ significantly from that of females

# %%
## 4c) is the proportion of smokers significantly different in different genders?

# %%
sns.countplot(data['smoker'],hue=data['sex'])

# %% [markdown]
# ### we see from visualization that proportion of smokers is significantly different in different genders

# %% [markdown]
# ### Ho = proportion of smokers are not significantly different in different genders i.e proportions are equal
# ### Ha = proportion of smokers significantly different in different genders

# %%
female=data[data['sex'] == 'female']
male=data[data['sex'] == 'male']
total_count=data.sex.value_counts()
female_count=data.sex.value_counts()[1]
male_count=data.sex.value_counts()[0]
print(total_count)
print(male_count)
print(female_count)
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# 676
# 662

# %%
female_smokers=female.smoker.value_counts()[1]
female_smokers
# Out:
# 115

# %%
male_smokers=male.smoker.value_counts()[1]
male_smokers
# Out:
# 159

# %%
from statsmodels.stats.proportion import proportions_ztest

stat, pval = proportions_ztest([female_smokers, male_smokers] , [female_count, male_count])

if pval < 0.05:
    print(f'With a p-value of {round(pval,4)} the difference is significant. aka |We reject the null|')
else:
    print(f'With a p-value of {round(pval,4)} the difference is not significant. aka |We fail to reject the null|')
# Out:
# With a p-value of 0.0053 the difference is significant. aka |We reject the null|

# %% [markdown]
# #### p-value of 0.0053 < 0.05.
# reject null hypothesis
# so, proportion of smokers significantly different in different genders
#
# Ho = proportion of smokers are not significantly different in different genders i.e proportions are equal
# Ha = proportion of smokers significantly different in different genders

# %% [markdown]
# ### so, we conclude proportion of smokers are significantly different in different genders

# %%
## 4d)Is the distribution of bmi across women with no children, one child and two children, the same?

# %% [markdown]
# ### Ho = "No. of children has no effect on bmi"
# ### Ha = "No. of children has an effect on bmi"

# %%
data.groupby(data[data['sex']=='female']['children'])['bmi'].mean().plot(kind='barh',color='Green')

# %% [markdown]
# ### we see from visualization that No. of children has no effect on bmi for females

# %%
female=data[data['sex'] == 'female']
male=data[data['sex'] == 'male']
total_count=data.sex.value_counts()
female_count=data.sex.value_counts()[1]
male_count=data.sex.value_counts()[0]
print(total_count)
print(male_count)
print(female_count)
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# 676
# 662

# %%
data.children.value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
female.children.value_counts()
# Out:
# 0    289
# 1    158
# 2    119
# 3     77
# 4     11
# 5      8
# Name: children, dtype: int64

# %%
male.children.value_counts()
# Out:
# 0    285
# 1    166
# 2    121
# 3     80
# 4     14
# 5     10
# Name: children, dtype: int64

# %%
female_no_child=female.children.value_counts()[0]
female_one_child=female.children.value_counts()[1]
female_two_child=female.children.value_counts()[2]
female_no_child
female_one_child
female_two_child
# Out:
# 119

# %%
female_one_child
# Out:
# 158

# %%
female_two_child
# Out:
# 119

# %%
np.array(female.children.value_counts()[0])
# Out:
# array(289, dtype=int64)

# %%
female_dataset=data[data['sex'] == 'female']

# %%
zerochild=female_dataset[female_dataset.children==0]['bmi']
onechild=female_dataset[female_dataset.children==1]['bmi']
twochild=female_dataset[female_dataset.children==2]['bmi']

# %%
zerochild
# Out:
# 0       27.90
# 5       25.74
# 9       25.84
# 11      26.29
# 13      39.82
#         ...
# 1331    33.40
# 1334    31.92
# 1335    36.85
# 1336    25.80
# 1337    29.07
# Name: bmi, Length: 289, dtype: float64

# %%
# Applying anova test to check the proportion.
import scipy.stats as stats

female=data[data['sex'] == 'female']
zerochild = female[female.children == 0]['bmi']
onechild = female[female.children == 1]['bmi']
twochild = female[female.children == 2]['bmi']

f_stat, p_value = stats.f_oneway(zerochild,onechild,twochild)
print(p_value)
# Out:
# 0.7158579926754841

# %% [markdown]
# #### p-value of 0.715 >0.05.
# #### accept null hypotheis
# ### so, we conclude No. of children has no effect on bmi for females
